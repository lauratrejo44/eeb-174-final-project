# %% [markdown]
# # Lightning Talk
# ## Laura Trejo
# ### ***Introductuion of Neotropical Birds***
#
#
#
# ### Why I chose this project ?
# I chose to focus on the evolutionary history of neoaves in North America and South America(netropic regions), because I was not able to get enough species. Originally I wanted to research the quetzal because I am Guatemalan and this is the national bird of Guatemala! Trogons are small family of of tropical birds. They are some of the most colorful birds. The best known is the Resplendant Quetzal of the Neotropics. Fossil evidence from Europe indicates their distribution was quite diffferent. Trogons are restricted to tropical forest.
#
# ### Trogones

# %% [markdown]
# ![image](/home/eeb177-student/Desktop/eeb-177/eeb-174-final-project/Quetzal.png)

# %%
from IPython.display import Image
Image(filename= '/home/eeb177-student/Desktop/eeb-177/eeb-174-final-project/Quetzal.png')

# %%
from IPython.display import Image
Image(filename= '/home/eeb177-student/Desktop/eeb-177/eeb-174-final-project/map.png')

# %%
from IPython.display import Image
Image(filename= '/home/eeb177-student/Desktop/eeb-177/eeb-174-final-project/pmap.png')

# %%
from IPython.display import Image
Image(filename= '/home/eeb177-student/Desktop/eeb-177/eeb-174-final-project/neotropical.png')

# %%
import csv

output = open("neoaves_extant.csv", "w")
#create and define function that takes an integer from the min_ma as the argument and returns either extanct or extinct

def still_exists(string):
    for ma in (item [11]):
         if ma == '0':
            exists.append (0)
            return ('0')
         else:
            exists.append(1)
            return('1')
            

#read in the file 
in_file = open ( "/home/eeb177-student/Desktop/eeb-177/eeb-174-final-project/neoaves/neoaves.csv")
#make a dictionary of taxon of either extinct or extanct 
#mames a list of 0 or 1 
taxon = {}
exists = []

#get rid of the header
in_file.readline()

list_species = [] #empty list to store species in
       
for line in in_file:
    species = line.split('","')[6]
    name_of_species = line.split('","')[5]
    if "species" in species:  
        list_species.append(name_of_species)
number_species = len ( list_species)


print (number_species)

print("\n".join(list_species)) #check to see if species list printed (works)
# Out:
# 111
# Ornimegalonyx oteroi
# Neogaeornis wetzeli
# Ramphastosula ramirezi
# Anhinga grandis
# Phalacrocorax bougainvillii
# Cruschedula revola
# Cladornis pachypus
# Kelenken guillermoi
# Psilopterus colzecus
# Puffinus lherminieri
# Pterodroma cahow
# Phaethon lepturus
# Leptoptilos patagonicus
# Taubatornis campbelli
# Hoazinoides magdalenae
# Argentavis magnificens
# Argentavis magnificens
# Argentavis magnificens
# Phalacrocorax brasilianus
# Patagornis marshi
# Palaeociconia australis
# Brontornis burmeisteri
# Brontornis burmeisteri
# Brontornis burmeisteri
# Phorusrhacos longissimus
# Phorusrhacos longissimus
# Phorusrhacos longissimus
# Phorusrhacos longissimus
# Phorusrhacos longissimus
# Mesembriornis milneedwardsi
# Patagornis marshi
# Psilopterus lemoinei
# Psilopterus bachmanni
# Dryornis pampeanus
# Phorusrhacos longissimus
# Phorusrhacos longissimus
# Phorusrhacos longissimus
# Phorusrhacos longissimus
# Phorusrhacos longissimus
# Lagopterus minutus
# ...

# %%
for line in in_file:
    
    #split so we can access the different columns in the lines 
    #items = line.split ('\t')
    #item = line.split('","')
    
    taxons = item [5]
    ma = item [11]

    #populate our dictionaries
    taxon[taxons] = still_exists (ma)
    
   # if item [11] == 0:
       # output.write(item[5] + '\n')
    print (taxons)

# %%
#open the file 

import csv

in_file = open ( "/home/eeb177-student/Desktop/eeb-177/eeb-174-final-project/neoaves/neoaves.csv")


#get rid of the header
in_file.readline()


# use default dict
from collections import defaultdict
species_ranges = defaultdict(list)

list_species = [] #empty list to store species in
       
for line in in_file:
    species = line.split('","')[6]
    name_of_species = line.split('","')[5]
    minage = line.split('","')[11]
    maxage = line.split('","')[10]
    mean_age = (float(minage) + float(maxage))/2
    if "species" in species:  
        list_species.append(name_of_species)
        species_ranges[name_of_species].append(mean_age) # add species as keys   
number_species = len ( list_species)
#print (number_species)

#print("\n".join(list_species)) #check to see if species list printed (works)

# make a dict
#for line in in_file: 
    #species = line.split(",")[5][1:-1]
   # minage = line.split('","')[11]
   
    #maxage = line.split('","')[10]
   # mean_age = (float(minage) + float(maxage))/2
   
    
    #species_ranges[list_species].append(mean_age) # add species as keys



#create an output file 
output = open("neoaves_trees.csv", "w")

#sort ouput so species are in alphabetical order 
sort_spp = sorted (species_ranges.keys())

#get oldest and youngest

for key in species_ranges:
    ages = species_ranges[key]
    minage = min(ages)
    maxage = max(ages)
    #genus = key.split(" ")[0]
    species = key
    outline= "{},{},{},\n".format(species, minage, maxage)
    output.write(outline)
    #print(outline)

# %%
from IPython.display import Image
Image(filename= '/home/eeb177-student/Desktop/eeb-177/eeb-174-final-project/tree.png')

# %%
#Plot the stratigraphic record 

from IPython.display import Image
Image(filename= '/home/eeb177-student/Desktop/eeb-177/eeb-174-final-project/paleo.png')

# %% [markdown]
# Gitlink: https://github.com/lauratrejo44/eeb-174-final-project/tree/master/eeb-174-final-project

# %% [markdown]
# References:
# 1. http://introtopython.org/visualization_earthquakes.html
# 2. http://nemagraptus.blogspot.com/2014/07/creating-pretty-plots-of-trees.html
# 3. https://books.google.com/books?hl=en&lr=&id=8QRKV7eSqmIC&oi=fnd&pg=PR8&dq=ornithurae+quetzal&ots=fqYaeQdBDd&sig=_Jgy0pIvc75YjRRKqGzceiMkTlc#v=onepage&q=quetzal&f=false
