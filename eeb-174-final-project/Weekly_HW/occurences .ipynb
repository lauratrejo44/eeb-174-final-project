# %%
import csv

in_file = open ( "/home/eeb177-student/Desktop/eeb-177/eeb-174-final-project/neoaves/neoaves.csv")


#get rid of the header
in_file.readline()


# use default dict
from collections import defaultdict
species_ranges = defaultdict(list)


       
for line in in_file:
    name_of_species = line.split('","')[5]
    minage = line.split('","')[11]
    maxage = line.split('","')[10]
    mean_age = (float(minage) + float(maxage))/2
    species_ranges[name_of_species].append(mean_age) # add species as keys

# %%
output = open("aves-ranges.csv", "w")
output1 = open("neoaves_trees.csv", "w")
header = "{}, {}, {},\n".format("Species","FA", "LA")
output1.write(header)

#get oldest and youngest
#species_ranges.values()
for key in species_ranges.keys():
    ages = species_ranges[key]
    minage = min(ages)
    maxage = max(ages)
    genus = key.split(" ")[0]
    species = key
    outline= "{},{},{},{}\n".format(genus, species, minage, maxage)
    output.write(outline)
    outline1 = "{},{},{},\n".format(species, minage, maxage)
    
    output1.write(outline1)
    #print(genus, key, minage, maxage)
    
    print(outline1)
# Out:
# Sulidae,13.789000000000001,13.789000000000001,
#
# Thalassarche,13.789000000000001,13.789000000000001,
#
# Ramphastosula aguierrei,6.2895,6.2895,
#
# Passeriformes,0.00585,0.00585,
#
# Physornis,25.0,25.0,
#
# Psilopteridae,10.6515,41.25,
#
# Cariama santacrucensis,16.9,16.9,
#
# Asio flammeus,0.06885,0.06885,
#
# Protibis,13.789000000000001,13.789000000000001,
#
# Eudocimus,0.00585,0.06885,
#
# Amplibuteo hibbardi,0.06885,0.06885,
#
# Bathoceleus hyphalus,1.29985,1.29985,
#
# Podiceps,0.00585,0.06885,
#
# Columbidae,0.00585,0.00585,
#
# Paleopsilopterus itaboraiensis,53.650000000000006,53.650000000000006,
#
# Ornimegalonyx oteroi,1.29985,1.29985,
#
# Athene,0.00585,0.00585,
#
# Circus,1.29985,1.29985,
#
# Argentavis magnificens,7.9,7.9,
#
# Pelecaniformes,9.433,9.433,
#
# Speotyto cunicularia,0.06885,1.29985,
#
# Phorusrhacinae,8.470500000000001,8.470500000000001,
#
# Corvus,0.00585,0.00585,
#
# Aegolius gradyi,0.06885,0.06885,
#
# Corvus wetmorei,1.29985,1.29985,
#
# Badiostes patagonicus,16.9,16.9,
#
# Mycteria,0.06885,0.06885,
#
# Phalacrocorax brasilianus,0.3965,0.3965,
#
# Falco,0.00585,1.29985,
#
# Milvago brodkorbi,0.06885,0.06885,
#
# Accipiter,0.00585,0.00585,
#
# Porzana,0.00585,0.06885,
#
# Ajaia,0.06885,0.06885,
#
# Patagornis marshi,13.789000000000001,16.9,
#
# Anhinga grandis,9.433,9.433,
#
# Syrigma sanctimartini,0.06885,0.06885,
#
# Glaucidium dickinsoni,1.29985,1.29985,
#
# Nycticorax,0.06885,1.29985,
#
# Andrewsornis,25.0,25.0,
#
# Diomedea,6.2895,6.2895,
#
# Porphyrula,0.00585,0.4535,
#
# Ardea,0.06885,0.06885,
#
# Hoazinoides magdalenae,8.470500000000001,8.470500000000001,
#
# Eudocimus peruvianus,0.06885,0.06885,
#
# Spizella,0.00585,0.00585,
#
# Miraquila terrestris,0.06885,0.06885,
#
# Columbina,0.00585,1.29985,
#
# Petrochelidon,0.00585,0.00585,
#
# Psilopterus colzecus,8.470500000000001,8.470500000000001,
#
# Buteo,0.06885,1.29985,
#
# Buteo lineatus,1.29985,1.29985,
#
# Sturnella,0.00585,0.00585,
#
# Morus peruvianus,6.2895,6.2895,
#
# Buteo jamaicensis,0.063,0.063,
#
# Tyto,0.00585,1.29985,
#
# Sula,6.2895,12.719999999999999,
#
# Foetopterus ambiguus,5.4,5.4,
#
# Liptornis hesternus,13.789000000000001,13.789000000000001,
#
# Sula sulita,6.2895,6.2895,
#
# Egretta,0.06885,0.06885,
#
# Sula figueroae,9.433,9.433,
#
# Lagopterus minutus,0.3965,0.3965,
#
# Puffinus,0.00585,3.0940000000000003,
#
# Dryornis pampeanus,5.4,5.4,
#
# Thegornis debilis,19.5,19.5,
#
# Devincenzia gallinali,25.0,25.0,
#
# Falconidae,0.00585,19.5,
#
# Falco sparverius,0.00585,0.06885,
#
# Motacillinae,0.4535,0.4535,
#
# Leptoptilos patagonicus,8.470500000000001,8.470500000000001,
#
# Procellariidae,6.2895,6.2895,
#
# Mesembriornis milneedwardsi,4.4665,5.4,
#
# Phalacrocorax bougainvillii,0.06885,3.0940000000000003,
#
# Psilopterus bachmanni,13.789000000000001,16.9,
#
# Phaethon lepturus,0.00585,0.00585,
#
# Sula brandi,9.433,9.433,
#
# Phoenicopteridae,7.9,7.9,
#
# Brontornis burmeisteri,13.789000000000001,19.5,
#
# Cladornis pachypus,28.465,28.465,
#
# Cruschedula revola,28.465,28.465,
#
# Zenaida,0.00585,1.29985,
#
# Phorusrhacidae,0.39635000000000004,25.0,
#
# Melanerpes,1.29985,1.29985,
#
# Fulmarus,6.2895,6.2895,
#
# Itaboravis elaphrocnemoides,53.650000000000006,53.650000000000006,
#
# Devincenzia,7.9,7.9,
#
# Puffinus lherminieri,0.00585,0.063,
#
# Sula magna,6.2895,9.433,
#
# Jabiru mycteria,0.06885,0.06885,
#
# Theristicus wetmorei,0.06885,0.06885,
#
# Podilymbus podiceps,0.06885,0.06885,
#
# Nyctanassa violacea,0.00585,0.00585,
#
# Anhinga,9.433,9.433,
#
# Otus providentiae,1.29985,1.29985,
#
# Neogaeornis wetzeli,68.3,68.3,
#
# Bubo virginianus,0.06885,0.06885,
#
# Contopus,0.00585,0.00585,
#
# Megapaloelodus,7.9,7.9,
#
# Chunga,4.4665,5.4,
#
# Caprimulgus piurensis,0.06885,0.06885,
#
# Rallus,0.00585,0.00585,
#
# Psittacidae,0.3965,0.3965,
#
# Ramphastosula ramirezi,6.2895,6.2895,
#
# Phorusrhacos longissimus,13.789000000000001,19.5,
#
# Zonotrichia,0.9904999999999999,0.9904999999999999,
#
# Diomedeidae,9.5,12.809000000000001,
#
# Opisthodactylus patagonicus,13.789000000000001,13.789000000000001,
#
# Rallidae,0.00585,7.9,
#
# Pandion,0.00585,0.00585,
#
# Eutreptodactylus itaboraiensis,53.650000000000006,53.650000000000006,
#
# Milvago,1.29985,3.0940000000000003,
#
# Rallus recessus,0.06885,0.06885,
#
# Anisolornis,13.789000000000001,13.789000000000001,
#
# Colaptes,0.00585,0.3965,
#
# Palaeociconia australis,5.4,5.4,
#
# Kelenken guillermoi,14.65,14.65,
#
# Taubatornis campbelli,22.185,22.185,
#
# Columba,0.00585,1.29985,
#
# Fulmarus glacialis,0.00585,0.00585,
#
# Coccyzus,0.00585,0.00585,
#
# Geranoaetus,0.06885,1.29985,
#
# Caracara plancus,0.06885,1.29985,
#
# Cariaminae,16.9,16.9,
#
# Rallus longirostris,0.00585,0.00585,
#
# Andalgalornis,7.9,7.9,
#
# Accipitridae,10.6515,10.6515,
#
# Fulica podagrica,0.063,0.063,
#
# Tyto alba,0.06885,1.29985,
#
# Ardeidae,41.25,41.25,
#
# Phalacrocorax,0.00585,9.433,
#
# Pterodroma cahow,0.00585,0.00585,
#
# Caracara creightoni,0.00585,1.29985,
#
# Psilopterus lemoinei,13.789000000000001,19.5,

# %%
##tree

#create an output file 


#sort ouput so species are in alphabetical order 

#get oldest and youngest

#for key in species_ranges:
   # ages = species_ranges[key]
   # minage = min(ages)
    #maxage = max(ages)
    #genus = key.split(" ")[0]
    #species = key
    
print(outline1)
# Out:
# Psilopterus lemoinei,13.789000000000001,19.5,
